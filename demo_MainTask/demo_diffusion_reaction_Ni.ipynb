# %% [markdown]
# <big>**①Model Description**</big>
#
# We have a $\mathrm{Ni} - \mathrm{SiC}$ pair,the metal interacts only with silicon forming silicides.(金属仅仅与硅相互作用形成硅化物。)
#
# This chemical interaction is the principal cause, which damages the rigid silicon-carbide lattice.(这种化学相互作用是破坏刚性碳化硅晶格的主要原因。)
#
# The reaction of the metal-monosilicide formation by an example of $\mathrm{Ni}$ has the form：
#
# $$\mathrm{Ni}+\mathrm{SiC}\longrightarrow\mathrm{NiSi}+\mathrm{C}\mathrm{~or~A}+\mathrm{BC}\xrightarrow{k_{11}}\mathrm{AB}+\mathrm{C}~~~~~~(1)$$
#
#  At relatively low annealing temperatures $(T = 600–950°C)$,the metal enriched silicide $(Ni2Si)$ is formed:
# $$\mathrm N\mathrm i+\mathrm N\mathrm i\mathrm S\mathrm i\longrightarrow\mathrm N\mathrm i_2\mathrm S\mathrm i\:\mathrm o\mathrm r\:\mathrm A+\mathrm A\mathrm B\xrightarrow{k_{21}}\mathrm A_2\mathrm B.~~~~~~(2)$$
#
#  At higher temperatures $(T = 950–1100°C)$,  and under proton irradiation it is nickel disilicide with liberation of carbon that is formed alongside with monosilicide in the reaction:
# $$\mathrm{NiSi}+\mathrm{SiC}\longrightarrow\mathrm{NiSi}_{2}+\mathrm{C}\mathrm{~or~AB}+\mathrm{AC}\xrightarrow{k_{12}}\mathrm{A}_{2}\mathrm{B}+\mathrm{C}.$$

# %% [markdown]
# Here, $k_{11}$, $k_{21}$, and $k_{12}$ are the rate constants for reactions (1), (2), and (3)  respectively.
#
# All these reactions proceed in the $\mathrm{SiC}$ bulk as a result of the diffusion penetration(渗透) of $\mathrm{Ni}$ into $\mathrm{SiC}$. The metal atoms and, probably, released $C$ atoms are the mobile components in reactions (1)–(3).
#
# For the relation $D_{A} \gg D_{C}$ between the diffusivities(扩散率/扩散系数)，wehave a displacement of the interphase boundary to the surface due to the Kirkendall effect.
#
# We assume that the diffusion mixing of $\mathrm{Ni}$, $\mathrm{Si}$ (in the $\mathrm{SiC}$ composition), and reduced $\mathrm{C}$ also can be described in the metal–$\mathrm{SiC}$ system by the effective heterodiffusion coefficient $\mathrm{D^*}$.

# %% [markdown]
# <big>**②Problem setup**</big>
#
# The diffusion–reaction equations for the components of reactions (1) - (4)  in the metal–$\mathrm{SiC}$ system has the form:
#
# $$\frac{\partial C_\mathrm{A}}{\partial t}\:=\:\frac{\partial}{\partial x}\biggl(D^*\frac{\partial C_\mathrm{A}}{\partial x}\biggr)-k_{11}C_\mathrm{A}C_\mathrm{BC}-k_{21}C_\mathrm{A}C_\mathrm{AB}~~~~~~(4)$$
#
# $$\frac{\partial C_{\mathrm{BC}}}{\partial t}\:=\:\frac{\partial}{\partial x}\biggl(D^*\frac{\partial C_{\mathrm{BC}}}{\partial x}\biggr)-k_{11}C_{\mathrm{A}}C_{\mathrm{BC}}-k_{12}C_{\mathrm{AB}}C_{\mathrm{BC}}~~~~~~(5)$$
#
# $$\frac{\partial C_{\mathrm{C}}}{\partial t}\:=\:\frac{\partial}{\partial x}\biggl(D^{*}\frac{\partial C_{\mathrm{C}}}{\partial x}\biggr)+k_{11}C_{\mathrm{A}}C_{\mathrm{BC}}+k_{12}C_{\mathrm{BC}}C_{\mathrm{AB}}~~~~~~(6)$$
#
# $$\frac{\partial C_{\mathrm{AB}}}{\partial t}\:=\:k_{11}C_{\mathrm{A}}C_{\mathrm{BC}}-k_{21}C_{\mathrm{A}}C_{\mathrm{AB}}~~~~~~(7)$$
#
# $$\frac{\partial C_{\mathrm{ABB}}}{\partial t}\:=\:k_{12}C_{\mathrm{BC}}C_{\mathrm{AB}}~~~~~~(8)$$
#
# $$\frac{\partial C_{\mathrm{AAB}}}{\partial t}\:=\:k_{21}C_{\mathrm{A}}C_{\mathrm{AB}}~~~~~~~(9)$$
#
# where $t$ is the time; $x$ is the depth (time dependent PDEs) ;
#
# $C_{?}$ are the concentrations of different components.
#
# The effective heterodiffusion coefficient has the following form in our case:
# $$D^{*}\:=\:\frac{D_{\mathrm{A}}(C_{\mathrm{BC}}+C_{\mathrm{C}}+C_{\mathrm{AB}}+C_{\mathrm{ABB}}+C_{\mathrm{AAB}})+D_{\mathrm{C}}C_{\mathrm{A}}}{C_{\Sigma}}~~~~~~(10)$$
#
# Here $C_{\Sigma}$ is the total concentration of all components.
#
# It was shown that $\mathrm{Ni}$  is the dominant mobile component, while carbon released in the interaction of $\mathrm{Ni}$ with $\mathrm{SiC}$. Therefore, we set $D_C = 0 $ in Eq(10).
#
# (反应中主要的移动成分是镍，而碳在镍和碳化硅的反应中被释放，因此我们设置碳在等式10的扩散系数为0)
#
# The metal diffusivity in various phases is   different; we assume that it linearly depends on composition:
#
# (各相金属扩散系数不同；我们假设它线性取决于成分：)
#
# $$D_A=\frac{D_{\mathrm{AA}}C_{\mathrm{A}}+D_{\mathrm{AB}}C_{\mathrm{AB}}+D_{\mathrm{ABB}}C_{\mathrm{ABB}}+D_{\mathrm{AAB}}C_{\mathrm{AAB}}+D_{\mathrm{BC}}C_{\mathrm{BC}}}{C_{\mathrm{A}}+C_{\mathrm{AB}}+C_{\mathrm{ABB}}+C_{\mathrm{AAB}}+C_{\mathrm{BC}}}\:~~~~~~(11)$$
#
# $D_?$ are the partial diffusivities of metal in the different phases(相).

# %% [markdown]
# The absence of diffusion terms in Eqs(7) - (9)  is caused by the fact that the plastic flow of material of silicides to the external surface due to the nickel atom flux is compensated in the steady state mode by the growth of silicidephase flow in an opposite direction (the Kirkendall effect).
#
# (在等式(7)-(9)中扩散项消失，这是由于在稳态模式下，硅化物材料因镍原子通量而向外表面产生的塑性流动被硅化物相向反方向流动的增长所补偿（柯肯达尔效应）。)

# %% [markdown]
# <big>**③Conditions**</big>
#
# $$C_{\mathrm{A}}(x,0)=N_{\mathrm{SA}}\:\mathrm{for}\:0\leq x\leq h~~~~~~(12)$$
#
# $$C_{\mathrm{B}}(x,0)=N_{\mathrm{SB}}\:\mathrm{for}\:h\leq x\leq L~~~~~~(13)$$
#
# $$C_{\mathrm{AB}}(x,0)=C_{\mathrm{ABB}}(x,0)=C_{\mathrm{AAB}}(x,0) =\:C_{\mathrm{C}}(x,0)\:=\:0\:\mathrm{for\:all}\:0\leq x\leq L~~~~~~(14)$$
#
# where $h$ is the metal film thickness, $\mathrm{L}$ is the $\mathrm{SiC}$ substrate thickness (the solutionregion depth)
#
# $\mathrm{N_{SA}}$  is the intrinsic metal-atom concentration ($9 × 10^{22} \mathrm{cm}^{-3}$)
#
# $\mathrm{N_{SB}}$  is the intrinsic silicon-atom concentration ($4.8 × 10^{22} \mathrm{cm}^{-3}$~~for $\mathrm{SiC}$)
#
# The boundary conditions correspond to the reflecting boundaries:
#
# $$\frac{\partial C_\mathrm{A}}{\partial x}\:=\:\frac{\partial C_\mathrm{BC}}{\partial x}\:=\:\frac{\partial C_\mathrm{C}}{\partial x}\:=\:0 \mathrm{~~for}\quad x\:=\:0\:\mathrm{and}\:x\:=\:L~~~~~~(15)$$
#
# Clearly this is a <u>**Neumann boundary condition**</u>, which is different from the Dirichlet boundary condition we used before.

# %% [markdown]
# <big>**④Reconstruct the system of partial differential equations**</big>
#
# $D^*$ is the function of concentration w.r.t $x$. Its derivative terms need to be considered. This processing ensures the correctness of the equation system and reflects the influence of concentration gradient and diffusion coefficient changes on substance migration.
#
# #To be refresh

# %% [markdown]
# <big>**⑤Different Conditinons**</big>
#
# For situation 1:
#
# In the metal–substrate diffusion pair with mobile metal atoms, the metal diffuses from the deposited film into the $\mathrm{SiC}$ substrate. As a result of the counter flow of vacancies and their subsequent annihilation at drains, there is the diffusion mixing of two materials.
#
# 在具有移动金属原子的金属-衬底扩散对中，金属从沉积薄膜扩散到 SiC 衬底中。由于空位的逆流及其随后在排水管处的湮灭，两种材料发生扩散混合。
#
# Here $k_{11}$, $k_{21}$ and $k_{12}$ are $0$. The caculation for $D_{A} = 6 \times 10^{-14} \mathrm{cm}^{2}/\mathrm{s}$.
#
# #To be refresh

# %% [markdown]
# <big>**Implementation**</big>
#
# This description goes through the implementation of a solver for the above described diffusion equation step-by-step

# %%
import deepxde as dde
import numpy as np
import torch

#changeable parameters
D_A = 6e-14
kf_11 = 0
kf_21 = 0
kf_12 = 0
h = 0.2 ##metal film thickness
L = 1  ##SiCsub strate thickness(the solutionregion depth)
time_length = 10
# Out:
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.

# %% [markdown]
# Next, we express the PDE residual of the diffusion-reaction equation:
#
# The first argument to pde is the 2 dimensional vector where the first component x[:, 0] is the $x$-coordinate; and the second component x[:, 1] is the $t$-coordinate.
#
# The second argument is the network output, i.e., the solution $C(x,t)$, but here we use $y$ as the name of the variable.

# %%
def pde(x,y): ##第一个x输入的是一个二维向量，第一个指的是x(j=0),第二个指的是t(j=1)。
    c_a,c_bc,c_c,c_ab,c_abb,c_aab = y[:, 0:1], y[:, 1:2],y[:, 2:3], y[:, 3:4],y[:, 4:5], y[:, 5:6]  ##6个等式，6个解

    #common variables
    C_sigma = c_a + c_bc + c_c + c_ab +c_abb + c_aab
    C_lambda = c_bc + c_c + c_ab +c_abb + c_aab

    D_star = D_A * (C_lambda/
                    C_sigma)
    
    dca_dx = dde.grad.jacobian(y, x, i=0, j=0)  ##Compute Jacobian matrix J as J[i, j] = dy_i / dx_j
    dcbc_dx = dde.grad.jacobian(y, x, i=1, j=0)
    dcc_dx = dde.grad.jacobian(y, x, i=2, j=0)
    dcab_dx = dde.grad.jacobian(y, x, i=3, j=0)
    dcabb_dx = dde.grad.jacobian(y, x, i=4, j=0)
    dcaab_dx = dde.grad.jacobian(y, x, i=5, j=0)

    dsigma_dx = dcbc_dx + dcc_dx + dcab_dx + dcabb_dx + dcaab_dx

    
    ##eq1:
    dca_dt = dde.grad.jacobian(y, x, i=0, j=1)  #t为x的 2-coordinate j=1
    dca_dxx = dde.grad.hessian(y, x, component=0, i=0, j=0) 
            #Compute Hessian matrix H as H[i, j] = d^2y / dx_i dx_j, where i,j = 0, …, dim_x - 1
            #Use component to select y_i = 0
    eq_1 = dca_dt - D_star * dca_dxx - dca_dx * \
        (D_A * (c_a * dsigma_dx - dca_dx * C_lambda)/ (C_sigma ** 2)) + \
        kf_11 * c_a * c_bc + kf_21 * c_a * c_ab 

    ##eq2:
    dcbc_dt = dde.grad.jacobian(y,x,i=1,j=1)  #t为x的 2-coordinate j=1
    dcbc_dxx = dde.grad.hessian(y,x,component=1,i=0,j=0)  ##cbc为y的 2-coordinate component =1
    eq_2 = dcbc_dt - D_star * dcbc_dxx - dcbc_dx * \
        (D_A * (c_a * dsigma_dx - dca_dx * C_lambda)/ (C_sigma ** 2)) + \
        kf_11 * c_a * c_bc + kf_12 * c_ab * c_bc 
    
    ##eq3
    dcc_dt = dde.grad.jacobian(y,x,i=2,j=1)  #t为x的 2-coordinate j=1
    dcc_dxx = dde.grad.hessian(y,x,component=2,i=0,j=0) ##cc为y的 3-coordinate component =2
    eq_3 = dcc_dt - D_star * dcc_dxx - dcc_dx * \
        (D_A * (c_a * dsigma_dx - dca_dx * C_lambda)/ (C_sigma ** 2)) - \
        kf_11 * c_a * c_bc - kf_12 * c_ab * c_bc 
    
    ##eq4
    dcab_dt = dde.grad.jacobian(y,x,i=3,j=1)
    eq_4 = dcab_dt - kf_11 * c_a * c_bc + kf_21 * c_a * c_ab 

    ##eq5
    dcabb_dt = dde.grad.jacobian(y,x,i=4,j=1)
    eq_5 = dcabb_dt - kf_12 * c_bc * c_ab
    ##eq6
    dcaab_dt = dde.grad.jacobian(y,x,i=5,j=1)
    eq_6 = dcaab_dt - kf_21 * c_a * c_ab 

    return [eq_1,eq_2,eq_3,eq_4,eq_5,eq_6]

# %% [markdown]
# Now we can define a computational geometry and time domain. By using a built-in class <u>Interval()</u> and <u>TimeDomain()</u>. And we combine both the domains using <u>GeometryXTime</u> as follows:

# %%
geom = dde.geometry.Interval(0, L)
timedomain = dde.geometry.TimeDomain(0, time_length)
geomtime = dde.geometry.GeometryXTime(geom, timedomain)

# %% [markdown]
# Next, we consider the Neumann boundary conditions and initial conditions:
#
# ##From The Result：maybe the setup of the IC is wrong!!!!!!

# %%
# 定义初始条件函数
N_SA = 9e22  # 替换为实际值
N_SB = 4.8e22  # 替换为实际值

# 定义Neumann边界条件
bc_neumann_C_A = dde.icbc.NeumannBC(geomtime, lambda x:0, lambda _, on_boundary:on_boundary,component=0)
bc_neumann_C_BC = dde.icbc.NeumannBC(geomtime, lambda x:0, lambda _, on_boundary:on_boundary,component=1)
bc_neumann_C_C = dde.icbc.NeumannBC(geomtime, lambda x:0, lambda _, on_boundary:on_boundary,component=2)

# def initial_condition_Ca(x):
#     initial_values = np.zeros_like(x[:, 0])
#     initial_values[x[:, 0] <= h] = N_SA
#     n = len(initial_values)
#     return initial_values.reshape((n,1))

# def initial_condition_Cb(x):
#     initial_values = np.zeros_like(x[:, 0])
#     initial_values[(x[:, 0] >= h) and (x[:, 0] <= L) ] = N_SB
#     n = len(initial_values)
#     return initial_values.reshape((n,1))

## A generic example
def fun_init(x):
    return np.exp(-20 * x[:, 0:1])

# def initial_condition_C_B(x):
#     return N_SB * (x[:, 0:1] >= h)

# def initial_condition_zeros(x):
#     return np.zeros_like(x[:, 0:1])

# 定义初始条件
ic_C_A = dde.icbc.IC(geomtime, fun_init, lambda _, on_initial: on_initial, component=0)
ic_C_BC = dde.icbc.IC(geomtime, fun_init, lambda _, on_initial: on_initial, component=1)
# ic_C_A = dde.icbc.IC(
#     geomtime, 
#     initial_condition_Ca, 
#     lambda _, on_initial: on_initial,component=0
# )
# ic_C_BC = dde.icbc.IC(
#     geomtime, 
#     initial_condition_Cb, 
#     lambda _, on_initial: on_initial,component=1
# )
ic_C_C = dde.icbc.IC(geomtime, lambda x:0, lambda _, on_initial: on_initial, component=2)
ic_C_AB = dde.icbc.IC(geomtime, lambda x:0, lambda _, on_initial: on_initial, component=3)
ic_C_ABB = dde.icbc.IC(geomtime, lambda x:0, lambda _, on_initial: on_initial, component=4)
ic_C_AAB = dde.icbc.IC(geomtime, lambda x:0, lambda _, on_initial: on_initial, component=5)

# 组合初始条件 combine IC
initial_conditions = [ic_C_A, ic_C_BC, ic_C_C, ic_C_AB, ic_C_ABB, ic_C_AAB]
# initial_conditions = [ic_zeros_C_C, ic_zeros_C_AB, ic_zeros_C_ABB, ic_zeros_C_AAB]

# %% [markdown]
# Now, we have specified the geometry and the PDE residual. We then define the TimePDE problem as:

# %%
data = dde.data.TimePDE(
    geomtime, 
    pde, 
    initial_conditions + [bc_neumann_C_A, bc_neumann_C_BC, bc_neumann_C_C], 
    num_domain=500, 
    num_boundary=100,
    num_initial=100, 
    num_test= 20000##we don't have solution = ? as a reference.
)
# Out:
# Warning: 20000 points required, but 20025 points sampled.

# %% [markdown]
# Now we create a network:

# %%
# 定义神经网络模型
net = dde.nn.FNN([2] + [20] * 3 + [6], "tanh", "Glorot normal")  
# Two inputs : x ,t
# Six outputs: c_a, c_bc, c_c, c_ab, c_abb, c_aab

# 定义模型
model = dde.Model(data, net)

# 编译模型
model.compile("adam", lr=1e-3)

# 训练模型
losshistory, train_state = model.train(iterations=40000)

# 可视化结果
dde.saveplot(losshistory, train_state, issave=True, isplot=True)
# Out:
# Compiling model...
# 'compile' took 1.290309 s
#
# Training model...
#
# Step      Train loss                                                                                                                                                Test loss                                                                                                                                                 Test metric
# 0         [2.50e-03, 2.28e-03, 4.65e-03, 1.35e-02, 1.27e-03, 6.95e-03, 3.65e-02, 2.57e-02, 5.16e-02, 3.80e-03, 6.45e-03, 2.09e-02, 1.60e-02, 4.33e-02, 2.81e-02]    [2.51e-03, 2.10e-03, 1.91e-03, 5.50e-03, 8.14e-04, 2.16e-03, 3.65e-02, 2.57e-02, 5.16e-02, 3.80e-03, 6.45e-03, 2.09e-02, 1.60e-02, 4.33e-02, 2.81e-02]    []
# 1000      [6.37e-04, 5.68e-04, 1.10e-05, 1.76e-04, 4.12e-05, 2.78e-05, 1.25e-02, 1.28e-02, 1.19e-05, 8.92e-05, 9.80e-06, 1.18e-06, 9.84e-04, 9.39e-04, 2.23e-05]    [4.52e-04, 3.81e-04, 7.60e-06, 9.67e-05, 2.42e-05, 2.45e-05, 1.25e-02, 1.28e-02, 1.19e-05, 8.92e-05, 9.80e-06, 1.18e-06, 9.84e-04, 9.39e-04, 2.23e-05]    []
# 2000      [2.90e-04, 3.01e-04, 2.34e-05, 4.99e-05, 1.91e-05, 1.67e-05, 1.10e-03, 1.09e-03, 3.70e-06, 5.31e-05, 2.04e-06, 4.02e-06, 8.42e-05, 1.12e-04, 4.23e-06]    [2.15e-04, 2.32e-04, 2.68e-05, 4.66e-05, 1.68e-05, 1.12e-05, 1.10e-03, 1.09e-03, 3.70e-06, 5.31e-05, 2.04e-06, 4.02e-06, 8.42e-05, 1.12e-04, 4.23e-06]    []
# 3000      [2.89e-04, 2.93e-04, 4.13e-05, 4.95e-05, 2.65e-05, 2.52e-05, 8.34e-04, 8.11e-04, 5.12e-06, 4.02e-05, 7.80e-06, 6.63e-06, 7.70e-05, 1.06e-04, 1.47e-05]    [1.66e-04, 2.34e-04, 4.58e-05, 5.02e-05, 2.41e-05, 1.92e-05, 8.34e-04, 8.11e-04, 5.12e-06, 4.02e-05, 7.80e-06, 6.63e-06, 7.70e-05, 1.06e-04, 1.47e-05]    []
# 4000      [2.75e-04, 2.71e-04, 1.91e-05, 3.54e-05, 1.84e-05, 1.84e-05, 5.82e-04, 5.65e-04, 3.45e-06, 3.80e-05, 6.55e-06, 6.79e-06, 5.32e-04, 6.08e-04, 7.88e-06]    [1.61e-04, 1.98e-04, 2.02e-05, 3.20e-05, 1.76e-05, 1.53e-05, 5.82e-04, 5.65e-04, 3.45e-06, 3.80e-05, 6.55e-06, 6.79e-06, 5.32e-04, 6.08e-04, 7.88e-06]    []
# 5000      [2.60e-04, 2.49e-04, 9.46e-06, 2.56e-05, 1.23e-05, 1.55e-05, 4.45e-04, 4.25e-04, 3.39e-06, 3.31e-05, 5.07e-06, 4.06e-06, 2.79e-05, 4.90e-05, 5.81e-06]    [1.56e-04, 1.81e-04, 1.01e-05, 2.17e-05, 1.22e-05, 1.30e-05, 4.45e-04, 4.25e-04, 3.39e-06, 3.31e-05, 5.07e-06, 4.06e-06, 2.79e-05, 4.90e-05, 5.81e-06]    []
# 6000      [2.46e-04, 2.32e-04, 5.80e-06, 1.73e-05, 8.17e-06, 1.22e-05, 3.53e-04, 3.37e-04, 2.72e-06, 2.73e-05, 4.78e-06, 2.83e-06, 1.72e-05, 3.54e-05, 5.21e-06]    [1.55e-04, 1.72e-04, 6.48e-06, 1.38e-05, 8.43e-06, 1.07e-05, 3.53e-04, 3.37e-04, 2.72e-06, 2.73e-05, 4.78e-06, 2.83e-06, 1.72e-05, 3.54e-05, 5.21e-06]    []
# 7000      [2.41e-04, 2.29e-04, 5.50e-06, 1.37e-05, 6.30e-06, 1.03e-05, 3.09e-04, 2.94e-04, 2.25e-06, 2.27e-05, 3.89e-06, 2.24e-06, 9.82e-06, 2.59e-05, 5.20e-06]    [1.53e-04, 1.68e-04, 6.15e-06, 1.05e-05, 6.35e-06, 9.03e-06, 3.09e-04, 2.94e-04, 2.25e-06, 2.27e-05, 3.89e-06, 2.24e-06, 9.82e-06, 2.59e-05, 5.20e-06]    []
# 8000      [4.45e-04, 4.31e-04, 1.28e-04, 1.25e-04, 1.99e-04, 1.10e-04, 4.32e-04, 5.25e-04, 1.71e-05, 2.63e-05, 3.07e-05, 3.29e-05, 1.33e-04, 7.60e-05, 3.33e-05]    [4.18e-04, 4.44e-04, 1.07e-04, 1.06e-04, 9.35e-05, 1.21e-04, 4.32e-04, 5.25e-04, 1.71e-05, 2.63e-05, 3.07e-05, 3.29e-05, 1.33e-04, 7.60e-05, 3.33e-05]    []
# 9000      [2.27e-02, 3.38e-02, 1.03e-02, 4.03e-03, 8.30e-04, 8.04e-03, 1.06e-01, 1.37e-01, 6.85e-02, 6.17e-02, 2.31e-02, 7.59e-02, 5.66e+00, 6.19e+00, 1.79e+00]    [1.92e-02, 3.31e-02, 9.10e-03, 3.82e-03, 1.02e-03, 6.79e-03, 1.06e-01, 1.37e-01, 6.85e-02, 6.17e-02, 2.31e-02, 7.59e-02, 5.66e+00, 6.19e+00, 1.79e+00]    []
# 10000     [2.27e-02, 3.38e-02, 1.03e-02, 4.03e-03, 8.29e-04, 8.04e-03, 1.06e-01, 1.36e-01, 6.84e-02, 6.17e-02, 2.31e-02, 7.59e-02, 5.64e+00, 6.18e+00, 1.80e+00]    [1.92e-02, 3.31e-02, 9.11e-03, 3.82e-03, 1.01e-03, 6.79e-03, 1.06e-01, 1.36e-01, 6.84e-02, 6.17e-02, 2.31e-02, 7.59e-02, 5.64e+00, 6.18e+00, 1.80e+00]    []
# 11000     [2.28e-02, 3.39e-02, 1.03e-02, 4.03e-03, 8.27e-04, 8.05e-03, 1.05e-01, 1.35e-01, 6.83e-02, 6.16e-02, 2.32e-02, 7.58e-02, 5.60e+00, 6.16e+00, 1.80e+00]    [1.92e-02, 3.31e-02, 9.12e-03, 3.82e-03, 1.01e-03, 6.79e-03, 1.05e-01, 1.35e-01, 6.83e-02, 6.16e-02, 2.32e-02, 7.58e-02, 5.60e+00, 6.16e+00, 1.80e+00]    []
# 12000     [2.28e-02, 3.40e-02, 1.04e-02, 4.03e-03, 8.23e-04, 8.06e-03, 1.04e-01, 1.34e-01, 6.80e-02, 6.16e-02, 2.34e-02, 7.56e-02, 5.54e+00, 6.12e+00, 1.80e+00]    [1.93e-02, 3.32e-02, 9.15e-03, 3.82e-03, 1.00e-03, 6.80e-03, 1.04e-01, 1.34e-01, 6.80e-02, 6.16e-02, 2.34e-02, 7.56e-02, 5.54e+00, 6.12e+00, 1.80e+00]    []
# 13000     [2.29e-02, 3.41e-02, 1.04e-02, 4.03e-03, 8.17e-04, 8.07e-03, 1.03e-01, 1.32e-01, 6.75e-02, 6.15e-02, 2.37e-02, 7.53e-02, 5.44e+00, 6.06e+00, 1.80e+00]    [1.93e-02, 3.33e-02, 9.19e-03, 3.81e-03, 9.94e-04, 6.80e-03, 1.03e-01, 1.32e-01, 6.75e-02, 6.15e-02, 2.37e-02, 7.53e-02, 5.44e+00, 6.06e+00, 1.80e+00]    []
# 14000     [2.29e-02, 3.42e-02, 1.05e-02, 4.03e-03, 8.04e-04, 8.09e-03, 1.00e-01, 1.29e-01, 6.68e-02, 6.13e-02, 2.42e-02, 7.48e-02, 5.26e+00, 5.96e+00, 1.81e+00]    [1.93e-02, 3.33e-02, 9.25e-03, 3.79e-03, 9.72e-04, 6.79e-03, 1.00e-01, 1.29e-01, 6.68e-02, 6.13e-02, 2.42e-02, 7.48e-02, 5.26e+00, 5.96e+00, 1.81e+00]    []
# 15000     [2.30e-02, 3.43e-02, 1.07e-02, 4.02e-03, 7.76e-04, 8.11e-03, 9.63e-02, 1.23e-01, 6.56e-02, 6.11e-02, 2.50e-02, 7.41e-02, 4.94e+00, 5.80e+00, 1.83e+00]    [1.92e-02, 3.33e-02, 9.36e-03, 3.75e-03, 9.28e-04, 6.77e-03, 9.63e-02, 1.23e-01, 6.56e-02, 6.11e-02, 2.50e-02, 7.41e-02, 4.94e+00, 5.80e+00, 1.83e+00]    []
# 16000     [2.28e-02, 3.41e-02, 1.10e-02, 3.98e-03, 7.12e-04, 8.09e-03, 8.98e-02, 1.14e-01, 6.38e-02, 6.07e-02, 2.64e-02, 7.29e-02, 4.34e+00, 5.50e+00, 1.89e+00]    [1.88e-02, 3.28e-02, 9.53e-03, 3.62e-03, 8.30e-04, 6.66e-03, 8.98e-02, 1.14e-01, 6.38e-02, 6.07e-02, 2.64e-02, 7.29e-02, 4.34e+00, 5.50e+00, 1.89e+00]    []
# 17000     [2.19e-02, 3.28e-02, 1.15e-02, 3.85e-03, 5.74e-04, 7.96e-03, 7.96e-02, 9.97e-02, 6.09e-02, 6.02e-02, 2.86e-02, 7.12e-02, 3.05e+00, 4.89e+00, 2.02e+00]    [1.73e-02, 3.07e-02, 9.81e-03, 3.30e-03, 6.22e-04, 6.33e-03, 7.96e-02, 9.97e-02, 6.09e-02, 6.02e-02, 2.86e-02, 7.12e-02, 3.05e+00, 4.89e+00, 2.02e+00]    []
# 18000     [1.94e-02, 2.97e-02, 1.24e-02, 3.66e-03, 4.25e-04, 7.75e-03, 6.59e-02, 7.81e-02, 5.62e-02, 5.95e-02, 3.18e-02, 6.87e-02, 9.80e-01, 3.50e+00, 2.05e+00]    [1.41e-02, 2.61e-02, 1.03e-02, 2.77e-03, 3.79e-04, 5.75e-03, 6.59e-02, 7.81e-02, 5.62e-02, 5.95e-02, 3.18e-02, 6.87e-02, 9.80e-01, 3.50e+00, 2.05e+00]    []
# 19000     [1.70e-02, 2.76e-02, 1.33e-02, 3.58e-03, 4.14e-04, 7.65e-03, 5.50e-02, 5.44e-02, 4.73e-02, 5.87e-02, 3.58e-02, 6.56e-02, 3.12e-01, 1.82e+00, 1.57e+00]    [1.17e-02, 2.33e-02, 1.07e-02, 2.46e-03, 3.07e-04, 5.43e-03, 5.50e-02, 5.44e-02, 4.73e-02, 5.87e-02, 3.58e-02, 6.56e-02, 3.12e-01, 1.82e+00, 1.57e+00]    []
# 20000     [1.48e-02, 2.65e-02, 1.40e-02, 3.53e-03, 4.46e-04, 7.63e-03, 5.33e-02, 3.60e-02, 3.43e-02, 5.72e-02, 3.94e-02, 6.19e-02, 4.79e-01, 7.42e-01, 9.54e-01]    [1.01e-02, 2.21e-02, 1.12e-02, 2.31e-03, 3.05e-04, 5.31e-03, 5.33e-02, 3.60e-02, 3.43e-02, 5.72e-02, 3.94e-02, 6.19e-02, 4.79e-01, 7.42e-01, 9.54e-01]    []
# 21000     [1.26e-02, 2.56e-02, 1.48e-02, 3.55e-03, 4.80e-04, 7.72e-03, 6.37e-02, 2.53e-02, 2.19e-02, 5.47e-02, 4.09e-02, 5.77e-02, 5.26e-01, 3.05e-01, 4.84e-01]    [8.48e-03, 2.14e-02, 1.19e-02, 2.26e-03, 3.18e-04, 5.30e-03, 6.37e-02, 2.53e-02, 2.19e-02, 5.47e-02, 4.09e-02, 5.77e-02, 5.26e-01, 3.05e-01, 4.84e-01]    []
# 22000     [1.03e-02, 2.47e-02, 1.54e-02, 3.68e-03, 4.90e-04, 7.89e-03, 8.54e-02, 1.97e-02, 1.49e-02, 5.00e-02, 3.83e-02, 5.30e-02, 3.25e-01, 1.86e-01, 2.27e-01]    [6.91e-03, 2.08e-02, 1.23e-02, 2.29e-03, 3.15e-04, 5.32e-03, 8.54e-02, 1.97e-02, 1.49e-02, 5.00e-02, 3.83e-02, 5.30e-02, 3.25e-01, 1.86e-01, 2.27e-01]    []
# 23000     [8.44e-03, 2.39e-02, 1.51e-02, 3.89e-03, 4.72e-04, 8.02e-03, 1.09e-01, 1.58e-02, 1.25e-02, 4.20e-02, 3.07e-02, 4.73e-02, 1.36e-01, 1.53e-01, 1.27e-01]    [5.63e-03, 2.03e-02, 1.19e-02, 2.40e-03, 2.91e-04, 5.30e-03, 1.09e-01, 1.58e-02, 1.25e-02, 4.20e-02, 3.07e-02, 4.73e-02, 1.36e-01, 1.53e-01, 1.27e-01]    []
# 24000     [7.24e-03, 2.32e-02, 1.38e-02, 4.14e-03, 4.51e-04, 8.02e-03, 1.15e-01, 1.31e-02, 1.19e-02, 3.12e-02, 1.99e-02, 3.91e-02, 6.60e-02, 1.38e-01, 9.32e-02]    [4.90e-03, 1.99e-02, 1.06e-02, 2.57e-03, 2.70e-04, 5.23e-03, 1.15e-01, 1.31e-02, 1.19e-02, 3.12e-02, 1.99e-02, 3.91e-02, 6.60e-02, 1.38e-01, 9.32e-02]    []
# 25000     [6.55e-03, 2.22e-02, 1.19e-02, 4.39e-03, 4.64e-04, 7.90e-03, 9.58e-02, 1.17e-02, 1.27e-02, 2.02e-02, 1.03e-02, 2.78e-02, 5.22e-02, 1.21e-01, 7.41e-02]    [4.63e-03, 1.93e-02, 8.93e-03, 2.78e-03, 2.86e-04, 5.14e-03, 9.58e-02, 1.17e-02, 1.27e-02, 2.02e-02, 1.03e-02, 2.78e-02, 5.22e-02, 1.21e-01, 7.41e-02]    []
# 26000     [5.92e-03, 2.07e-02, 1.02e-02, 4.59e-03, 5.28e-04, 7.59e-03, 6.36e-02, 9.92e-03, 1.38e-02, 1.08e-02, 4.52e-03, 1.58e-02, 4.88e-02, 9.69e-02, 6.06e-02]    [4.46e-03, 1.84e-02, 7.34e-03, 2.96e-03, 3.47e-04, 4.94e-03, 6.36e-02, 9.92e-03, 1.38e-02, 1.08e-02, 4.52e-03, 1.58e-02, 4.88e-02, 9.69e-02, 6.06e-02]    []
# 27000     [5.08e-03, 1.86e-02, 8.64e-03, 4.60e-03, 6.18e-04, 6.93e-03, 3.37e-02, 6.93e-03, 1.28e-02, 5.16e-03, 2.53e-03, 7.15e-03, 4.36e-02, 6.89e-02, 5.15e-02]    [4.15e-03, 1.70e-02, 5.99e-03, 2.99e-03, 4.19e-04, 4.48e-03, 3.37e-02, 6.93e-03, 1.28e-02, 5.16e-03, 2.53e-03, 7.15e-03, 4.36e-02, 6.89e-02, 5.15e-02]    []
# 28000     [4.14e-03, 1.61e-02, 7.12e-03, 4.32e-03, 6.90e-04, 5.91e-03, 1.48e-02, 4.15e-03, 8.43e-03, 2.95e-03, 2.27e-03, 3.55e-03, 3.49e-02, 4.35e-02, 4.26e-02]    [3.67e-03, 1.50e-02, 4.82e-03, 2.77e-03, 4.57e-04, 3.72e-03, 1.48e-02, 4.15e-03, 8.43e-03, 2.95e-03, 2.27e-03, 3.55e-03, 3.49e-02, 4.35e-02, 4.26e-02]    []
# 29000     [3.28e-03, 1.34e-02, 5.28e-03, 3.82e-03, 7.31e-04, 4.71e-03, 6.77e-03, 2.48e-03, 3.52e-03, 2.15e-03, 2.42e-03, 2.14e-03, 2.49e-02, 2.58e-02, 3.01e-02]    [3.09e-03, 1.27e-02, 3.54e-03, 2.35e-03, 4.65e-04, 2.81e-03, 6.77e-03, 2.48e-03, 3.52e-03, 2.15e-03, 2.42e-03, 2.14e-03, 2.49e-02, 2.58e-02, 3.01e-02]    []
# 30000     [2.52e-03, 1.09e-02, 3.50e-03, 3.24e-03, 7.52e-04, 3.56e-03, 4.81e-03, 1.52e-03, 1.14e-03, 1.67e-03, 2.59e-03, 1.21e-03, 1.63e-02, 1.35e-02, 1.66e-02]    [2.44e-03, 1.02e-02, 2.32e-03, 1.87e-03, 4.60e-04, 1.96e-03, 4.81e-03, 1.52e-03, 1.14e-03, 1.67e-03, 2.59e-03, 1.21e-03, 1.63e-02, 1.35e-02, 1.66e-02]    []
# 31000     [1.81e-03, 8.56e-03, 2.21e-03, 2.66e-03, 7.73e-04, 2.58e-03, 3.99e-03, 8.96e-04, 3.57e-04, 1.21e-03, 2.60e-03, 4.60e-04, 1.04e-02, 6.31e-03, 6.36e-03]    [1.86e-03, 7.98e-03, 1.45e-03, 1.47e-03, 4.71e-04, 1.33e-03, 3.99e-03, 8.96e-04, 3.57e-04, 1.21e-03, 2.60e-03, 4.60e-04, 1.04e-02, 6.31e-03, 6.36e-03]    []
# 32000     [1.15e-03, 6.43e-03, 1.46e-03, 2.10e-03, 7.40e-04, 1.81e-03, 4.06e-03, 7.83e-04, 2.57e-04, 9.28e-04, 2.09e-03, 1.60e-04, 6.34e-03, 2.96e-03, 1.62e-03]    [1.33e-03, 6.06e-03, 9.36e-04, 1.12e-03, 4.36e-04, 8.82e-04, 4.06e-03, 7.83e-04, 2.57e-04, 9.28e-04, 2.09e-03, 1.60e-04, 6.34e-03, 2.96e-03, 1.62e-03]    []
# 33000     [7.22e-04, 4.67e-03, 1.07e-03, 1.59e-03, 6.13e-04, 1.26e-03, 3.80e-03, 8.66e-04, 2.27e-04, 7.26e-04, 1.18e-03, 7.30e-05, 3.89e-03, 1.78e-03, 4.56e-04]    [9.19e-04, 4.57e-03, 6.49e-04, 8.34e-04, 3.27e-04, 6.00e-04, 3.80e-03, 8.66e-04, 2.27e-04, 7.26e-04, 1.18e-03, 7.30e-05, 3.89e-03, 1.78e-03, 4.56e-04]    []
# 34000     [5.61e-04, 3.28e-03, 7.76e-04, 1.13e-03, 4.40e-04, 8.61e-04, 3.29e-03, 9.27e-04, 2.10e-04, 5.30e-04, 4.53e-04, 5.07e-05, 2.61e-03, 1.20e-03, 2.56e-04]    [6.79e-04, 3.38e-03, 4.45e-04, 5.84e-04, 1.95e-04, 4.21e-04, 3.29e-03, 9.27e-04, 2.10e-04, 5.30e-04, 4.53e-04, 5.07e-05, 2.61e-03, 1.20e-03, 2.56e-04]    []
# 35000     [5.34e-04, 2.19e-03, 4.79e-04, 7.10e-04, 2.96e-04, 5.66e-04, 2.65e-03, 8.55e-04, 1.93e-04, 3.33e-04, 1.48e-04, 3.72e-05, 1.87e-03, 7.58e-04, 1.86e-04]    [5.40e-04, 2.39e-03, 2.58e-04, 3.63e-04, 1.05e-04, 2.98e-04, 2.65e-03, 8.55e-04, 1.93e-04, 3.33e-04, 1.48e-04, 3.72e-05, 1.87e-03, 7.58e-04, 1.86e-04]    []
# 36000     [5.00e-04, 1.36e-03, 2.38e-04, 3.73e-04, 1.98e-04, 3.47e-04, 1.98e-03, 7.11e-04, 1.33e-04, 1.84e-04, 6.00e-05, 2.64e-05, 1.21e-03, 4.63e-04, 1.51e-04]    [4.36e-04, 1.59e-03, 1.19e-04, 1.90e-04, 6.34e-05, 2.06e-04, 1.98e-03, 7.11e-04, 1.33e-04, 1.84e-04, 6.00e-05, 2.64e-05, 1.21e-03, 4.63e-04, 1.51e-04]    []
# 37000     [4.33e-04, 8.03e-04, 9.92e-05, 1.56e-04, 1.39e-04, 1.90e-04, 1.41e-03, 5.81e-04, 6.88e-05, 9.81e-05, 2.71e-05, 2.29e-05, 6.10e-04, 3.25e-04, 1.53e-04]    [3.56e-04, 1.01e-03, 4.36e-05, 8.28e-05, 5.52e-05, 1.35e-04, 1.41e-03, 5.81e-04, 6.88e-05, 9.81e-05, 2.71e-05, 2.29e-05, 6.10e-04, 3.25e-04, 1.53e-04]    []
# 38000     [5.08e-04, 6.49e-04, 5.22e-05, 8.39e-05, 9.28e-05, 2.01e-04, 1.07e-03, 5.66e-04, 7.88e-05, 5.19e-05, 1.51e-05, 5.67e-05, 2.56e-04, 3.14e-04, 1.42e-04]    [3.69e-04, 8.43e-04, 2.97e-05, 5.14e-05, 6.41e-05, 1.45e-04, 1.07e-03, 5.66e-04, 7.88e-05, 5.19e-05, 1.51e-05, 5.67e-05, 2.56e-04, 3.14e-04, 1.42e-04]    []
# 39000     [3.55e-04, 4.52e-04, 3.09e-05, 5.38e-05, 8.95e-05, 1.14e-04, 9.36e-04, 5.13e-04, 3.18e-05, 3.29e-05, 5.99e-06, 3.72e-05, 1.52e-04, 2.15e-04, 1.26e-04]    [3.00e-04, 5.92e-04, 1.71e-05, 3.50e-05, 6.48e-05, 9.03e-05, 9.36e-04, 5.13e-04, 3.18e-05, 3.29e-05, 5.99e-06, 3.72e-05, 1.52e-04, 2.15e-04, 1.26e-04]    []
# 40000     [2.95e-04, 3.35e-04, 3.04e-05, 3.36e-05, 7.28e-05, 7.59e-05, 7.38e-04, 4.72e-04, 2.07e-05, 2.50e-05, 4.71e-06, 3.15e-05, 1.07e-04, 1.59e-04, 1.04e-04]    [2.59e-04, 4.28e-04, 1.62e-05, 2.50e-05, 5.20e-05, 6.35e-05, 7.38e-04, 4.72e-04, 2.07e-05, 2.50e-05, 4.71e-06, 3.15e-05, 1.07e-04, 1.59e-04, 1.04e-04]    []
#
# Best model at step 7000:
#   train loss: 1.18e-03
#   test loss: 1.03e-03
#   test metric: []
#
# 'train' took 780.059765 s
#
# Saving loss history to h:\毕业论文\demo\Demo\loss.dat ...
# Saving training data to h:\毕业论文\demo\Demo\train.dat ...
# Saving test data to h:\毕业论文\demo\Demo\test.dat ...
