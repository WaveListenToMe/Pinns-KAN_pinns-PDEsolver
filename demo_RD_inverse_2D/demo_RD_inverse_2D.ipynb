# %% [markdown]
# To solve an inverse problem for diffusion-reaction systems for unknowns $D$ and $k_f$
#
# $\frac{\partial C_A}{\partial t}=D\frac{\partial^2C_A}{\partial x^2}-k_fC_AC_B^2,\\\frac{\partial C_B}{\partial t}=D\frac{\partial^2C_B}{\partial x^2}-2k_fC_AC_B^2$
#
# for $x \in [0,1]$ and $t \in [0,10]$ initial conditions
#
# $C_A(x,0)=C_B(x,0)=e^{-20x}$
#
# and boundary conditions
#
# $\begin{gathered}
# C_A(0,t)=C_B(0,t)=1 \\
# C_A(1,t)=C_B(1,t)=0.
# \end{gathered}$
#
# expected values of $D$ and $k_f$ are $2\cdot10^{-3} $ and $0.1$
#
# Implementation

# %%
import deepxde as dde
import numpy as np
import torch

# %% [markdown]
# Now, we define the unknown variables $D$ and $k_f$ with initial guesses of 1 and 0.05, respectively:

# %%
D = dde.Variable(1.0)
kf = dde.Variable(0.05)

# %% [markdown]
# We define the computational geometries by using the built-in <u>**Interval()</u>** and <u>**TimeDomain()**</u> combining them with <u>**GeometryXTime()**</u>

# %%
geom = dde.geometry.Interval(0, 1)  #x的边界条件
timedomain = dde.geometry.TimeDomain(0, 10)  #t的边界条件
geomtime = dde.geometry.GeometryXTime(geom, timedomain)  ##combine

# %% [markdown]
# Now, we create the reaction-inverse PDE:
#
# ues Jacobian to represent 1-order Partial derivative
#
# use Hessian to represent 2-order Partial derivative
#
# Here, the first parameter is the $t$-coordinate, and it is represented by $x$
#
# The second parameter has $C_A$ and $C_B$, which are represented by $y$.

# %%
def pde(x, y):
    ca, cb = y[:, 0:1], y[:, 1:2]  ##多维数组的切片语法
    dca_t = dde.grad.jacobian(y, x, i=0, j=1)
    dca_xx = dde.grad.hessian(y, x, component=0, i=0, j=0)##等式1 eq_a

    dcb_t = dde.grad.jacobian(y, x, i=1, j=1)
    dcb_xx = dde.grad.hessian(y, x, component=1, i=0, j=0)##等式2 eq_b

    eq_a = dca_t - 1e-3 * D * dca_xx + kf * ca * cb ** 2
    eq_b = dcb_t - 1e-3 * D * dcb_xx + 2 * kf * ca * cb ** 2 
    ##构造了偏微分方程组
    return [eq_a, eq_b]

# %% [markdown]
# Next, we consider the Dirichlet boundary conditions and initial conditions:

# %%
def fun_bc(x):  ##boundary conditions 边界条件
    return 1 - x[:, 0:1]

def fun_init(x): ##initial conditions 初始条件
    return np.exp(-20 * x[:, 0:1])

##边界条件的构造
bc_a = dde.icbc.DirichletBC(
    geomtime, fun_bc, lambda _, on_boundary: on_boundary, component=0
)

bc_b = dde.icbc.DirichletBC(
    geomtime, fun_bc, lambda _, on_boundary: on_boundary, component=1
)

##初始条件的构造
ic1 = dde.icbc.IC(geomtime, fun_init, lambda _, on_initial: on_initial, component=0)
ic2 = dde.icbc.IC(geomtime, fun_init, lambda _, on_initial: on_initial, component=1)

# %% [markdown]
# Now, we generate the training data：

# %%
def gen_traindata():
    data = np.load("reaction.npz")
    t, x, ca, cb = data["t"], data["x"], data["Ca"], data["Cb"]
    X, T = np.meshgrid(x, t)
    X = np.reshape(X, (-1, 1))  ##reshape为一个 一列的二维数组
    T = np.reshape(T, (-1, 1))
    Ca = np.reshape(ca, (-1, 1))
    Cb = np.reshape(cb, (-1, 1))
    return np.hstack((X, T)), Ca, Cb  ##堆叠数组

# %% [markdown]
# After generating the data, we organize it:

# %%
observe_x, Ca, Cb = gen_traindata()
observe_y1 = dde.icbc.PointSetBC(observe_x, Ca, component=0)
observe_y2 = dde.icbc.PointSetBC(observe_x, Cb, component=1)

# %% [markdown]
# Now, we can define the <u>**TimePDE**</u> problem as follows:

# %%
data = dde.data.TimePDE(
    geomtime,
    pde,
    [bc_a, bc_b, ic1, ic2, observe_y1, observe_y2],
    num_domain=2000,
    num_boundary=100,
    num_initial=100,
    anchors=observe_x,
    num_test=50000,
)
# Out:
# Warning: 50000 points required, but 50055 points sampled.

# %% [markdown]
# We have 2000 training residual points in the domain, 100 points on the boundary, 100 points for the initial conditions, and 50000 to test the PDE residual. anchors specifies the training points as well.
#
# Now, we create the network:

# %%
net = dde.nn.FNN([2] + [20] * 3 + [2], "tanh", "Glorot uniform")

# %% [markdown]
# This network has two inputs, one for the $t$-coordinate and one for the $x$-coordinate, and three hidden layers with 20 neurons each.
#
# The output layer has two outputs, one for $C_A$ and one for $C_B$.
#
# Activation: tanh; Initializer: Glorot uniform.
#
# Now, we create the <u>Model</u> and specify the optimizer, learning rate, and <u>external_trainable_variables</u>.
# Also output the values of $D$ and $k_f$ every 1000 iterations.

# %%
model = dde.Model(data, net)
model.compile("adam", lr=0.001, external_trainable_variables=[kf, D])
variable = dde.callbacks.VariableValue([kf, D], period=1000, filename="variables.dat")
# Out:
# Compiling model...
# 'compile' took 0.000587 s

# %%
losshistory, train_state = model.train(iterations=80000, callbacks=[variable])
dde.saveplot(losshistory, train_state, issave=True, isplot=True)
# Out:
# Training model...
#
# Step      Train loss                                                                          Test loss                                                                           Test metric
# 0         [1.65e-03, 1.55e-03, 5.97e-01, 6.55e-01, 2.88e-02, 6.76e-02, 9.15e-02, 1.04e-01]    [1.63e-03, 1.55e-03, 5.97e-01, 6.55e-01, 2.88e-02, 6.76e-02, 9.15e-02, 1.04e-01]    []
# 1000      [1.68e-04, 1.78e-04, 3.59e-04, 3.53e-04, 6.46e-04, 7.15e-04, 2.59e-04, 1.40e-04]    [1.31e-04, 1.35e-04, 3.59e-04, 3.53e-04, 6.46e-04, 7.15e-04, 2.59e-04, 1.40e-04]    []
# 2000      [4.95e-05, 7.69e-05, 6.19e-05, 7.06e-05, 1.09e-04, 1.42e-04, 5.26e-05, 6.37e-05]    [3.92e-05, 6.30e-05, 6.19e-05, 7.06e-05, 1.09e-04, 1.42e-04, 5.26e-05, 6.37e-05]    []
# 3000      [5.66e-05, 6.21e-05, 3.47e-04, 3.56e-04, 7.95e-05, 5.03e-05, 1.96e-04, 1.84e-04]    [5.02e-05, 5.20e-05, 3.47e-04, 3.56e-04, 7.95e-05, 5.03e-05, 1.96e-04, 1.84e-04]    []
# 4000      [4.52e-05, 5.23e-05, 1.75e-05, 2.01e-05, 2.28e-05, 1.98e-05, 3.38e-05, 4.80e-05]    [3.96e-05, 4.61e-05, 1.75e-05, 2.01e-05, 2.28e-05, 1.98e-05, 3.38e-05, 4.80e-05]    []
# 5000      [4.29e-05, 4.62e-05, 1.31e-05, 1.49e-05, 1.69e-05, 1.43e-05, 2.69e-05, 4.33e-05]    [3.73e-05, 4.06e-05, 1.31e-05, 1.49e-05, 1.69e-05, 1.43e-05, 2.69e-05, 4.33e-05]    []
# 6000      [4.00e-05, 4.21e-05, 1.03e-05, 1.30e-05, 1.35e-05, 1.13e-05, 2.28e-05, 3.98e-05]    [3.45e-05, 3.69e-05, 1.03e-05, 1.30e-05, 1.35e-05, 1.13e-05, 2.28e-05, 3.98e-05]    []
# 7000      [3.67e-05, 3.89e-05, 8.21e-06, 1.17e-05, 1.14e-05, 9.30e-06, 1.98e-05, 3.71e-05]    [3.13e-05, 3.42e-05, 8.21e-06, 1.17e-05, 1.14e-05, 9.30e-06, 1.98e-05, 3.71e-05]    []
# 8000      [3.31e-05, 3.64e-05, 6.62e-06, 1.04e-05, 1.01e-05, 7.81e-06, 1.74e-05, 3.47e-05]    [2.80e-05, 3.20e-05, 6.62e-06, 1.04e-05, 1.01e-05, 7.81e-06, 1.74e-05, 3.47e-05]    []
# 9000      [2.94e-05, 3.45e-05, 5.46e-06, 8.75e-06, 9.14e-06, 6.70e-06, 1.52e-05, 3.27e-05]    [2.48e-05, 3.02e-05, 5.46e-06, 8.75e-06, 9.14e-06, 6.70e-06, 1.52e-05, 3.27e-05]    []
# 10000     [2.57e-05, 3.29e-05, 4.62e-06, 8.08e-06, 8.39e-06, 5.59e-06, 1.29e-05, 2.96e-05]    [2.17e-05, 2.88e-05, 4.62e-06, 8.08e-06, 8.39e-06, 5.59e-06, 1.29e-05, 2.96e-05]    []
# 11000     [2.22e-05, 3.16e-05, 3.86e-06, 6.91e-06, 7.85e-06, 4.73e-06, 1.06e-05, 2.72e-05]    [1.87e-05, 2.76e-05, 3.86e-06, 6.91e-06, 7.85e-06, 4.73e-06, 1.06e-05, 2.72e-05]    []
# 12000     [1.91e-05, 3.08e-05, 7.15e-06, 1.23e-05, 7.31e-06, 4.02e-06, 8.61e-06, 2.21e-05]    [1.61e-05, 2.71e-05, 7.15e-06, 1.23e-05, 7.31e-06, 4.02e-06, 8.61e-06, 2.21e-05]    []
# 13000     [1.66e-05, 3.00e-05, 2.67e-06, 4.79e-06, 6.83e-06, 3.39e-06, 6.66e-06, 2.18e-05]    [1.40e-05, 2.56e-05, 2.67e-06, 4.79e-06, 6.83e-06, 3.39e-06, 6.66e-06, 2.18e-05]    []
# 14000     [1.46e-05, 2.94e-05, 2.34e-06, 4.17e-06, 6.28e-06, 2.90e-06, 5.26e-06, 1.87e-05]    [1.22e-05, 2.47e-05, 2.34e-06, 4.17e-06, 6.28e-06, 2.90e-06, 5.26e-06, 1.87e-05]    []
# 15000     [1.30e-05, 2.86e-05, 4.33e-06, 4.01e-06, 7.15e-06, 3.96e-06, 6.50e-06, 1.72e-05]    [1.08e-05, 2.37e-05, 4.33e-06, 4.01e-06, 7.15e-06, 3.96e-06, 6.50e-06, 1.72e-05]    []
# 16000     [1.20e-05, 2.79e-05, 1.76e-06, 2.80e-06, 5.18e-06, 2.30e-06, 3.64e-06, 1.34e-05]    [9.91e-06, 2.26e-05, 1.76e-06, 2.80e-06, 5.18e-06, 2.30e-06, 3.64e-06, 1.34e-05]    []
# 17000     [1.09e-05, 2.64e-05, 3.47e-06, 3.90e-06, 5.12e-06, 2.90e-06, 4.63e-06, 1.51e-05]    [8.83e-06, 2.05e-05, 3.47e-06, 3.90e-06, 5.12e-06, 2.90e-06, 4.63e-06, 1.51e-05]    []
# 18000     [1.23e-05, 2.72e-05, 1.15e-04, 1.54e-04, 1.98e-05, 2.52e-05, 5.11e-05, 8.33e-05]    [9.80e-06, 1.81e-05, 1.15e-04, 1.54e-04, 1.98e-05, 2.52e-05, 5.11e-05, 8.33e-05]    []
# 19000     [9.26e-06, 2.38e-05, 1.61e-06, 1.70e-06, 4.02e-06, 1.96e-06, 2.95e-06, 7.44e-06]    [7.47e-06, 1.78e-05, 1.61e-06, 1.70e-06, 4.02e-06, 1.96e-06, 2.95e-06, 7.44e-06]    []
# 20000     [8.82e-06, 2.24e-05, 1.75e-05, 2.43e-05, 5.61e-06, 6.63e-06, 9.14e-06, 2.02e-05]    [6.94e-06, 1.53e-05, 1.75e-05, 2.43e-05, 5.61e-06, 6.63e-06, 9.14e-06, 2.02e-05]    []
# 21000     [7.33e-06, 2.03e-05, 1.15e-06, 1.40e-06, 2.95e-06, 1.77e-06, 2.43e-06, 4.72e-06]    [5.83e-06, 1.46e-05, 1.15e-06, 1.40e-06, 2.95e-06, 1.77e-06, 2.43e-06, 4.72e-06]    []
# 22000     [6.46e-06, 1.87e-05, 1.03e-06, 1.21e-06, 2.67e-06, 1.69e-06, 2.28e-06, 3.90e-06]    [5.12e-06, 1.32e-05, 1.03e-06, 1.21e-06, 2.67e-06, 1.69e-06, 2.28e-06, 3.90e-06]    []
# 23000     [5.72e-06, 1.71e-05, 1.01e-06, 1.06e-06, 2.53e-06, 1.60e-06, 2.16e-06, 3.34e-06]    [4.52e-06, 1.19e-05, 1.01e-06, 1.06e-06, 2.53e-06, 1.60e-06, 2.16e-06, 3.34e-06]    []
# 24000     [5.15e-06, 1.56e-05, 6.32e-06, 4.56e-06, 9.08e-06, 5.57e-06, 8.66e-06, 6.64e-06]    [4.11e-06, 1.09e-05, 6.32e-06, 4.56e-06, 9.08e-06, 5.57e-06, 8.66e-06, 6.64e-06]    []
# 25000     [4.33e-06, 1.40e-05, 6.72e-06, 8.92e-06, 3.21e-06, 2.11e-06, 4.59e-06, 3.19e-06]    [3.46e-06, 1.03e-05, 6.72e-06, 8.92e-06, 3.21e-06, 2.11e-06, 4.59e-06, 3.19e-06]    []
# 26000     [4.01e-06, 1.27e-05, 4.47e-06, 8.54e-06, 2.49e-06, 3.94e-06, 2.97e-06, 7.32e-06]    [3.15e-06, 8.29e-06, 4.47e-06, 8.54e-06, 2.49e-06, 3.94e-06, 2.97e-06, 7.32e-06]    []
# 27000     [3.40e-06, 1.13e-05, 1.05e-06, 1.07e-06, 2.12e-06, 1.46e-06, 1.59e-06, 2.35e-06]    [2.69e-06, 7.78e-06, 1.05e-06, 1.07e-06, 2.12e-06, 1.46e-06, 1.59e-06, 2.35e-06]    []
# 28000     [2.99e-06, 1.00e-05, 6.33e-07, 8.05e-07, 1.93e-06, 1.40e-06, 1.10e-06, 1.59e-06]    [2.41e-06, 7.02e-06, 6.33e-07, 8.05e-07, 1.93e-06, 1.40e-06, 1.10e-06, 1.59e-06]    []
# 29000     [2.61e-06, 8.83e-06, 6.05e-07, 7.50e-07, 1.88e-06, 1.41e-06, 9.68e-07, 1.41e-06]    [2.11e-06, 6.18e-06, 6.05e-07, 7.50e-07, 1.88e-06, 1.41e-06, 9.68e-07, 1.41e-06]    []
# 30000     [2.33e-06, 7.70e-06, 6.09e-07, 7.92e-07, 1.88e-06, 1.53e-06, 9.22e-07, 1.40e-06]    [1.87e-06, 5.38e-06, 6.09e-07, 7.92e-07, 1.88e-06, 1.53e-06, 9.22e-07, 1.40e-06]    []
# 31000     [2.16e-06, 6.65e-06, 6.67e-06, 9.29e-06, 2.95e-06, 3.11e-06, 3.38e-06, 5.07e-06]    [1.71e-06, 4.40e-06, 6.67e-06, 9.29e-06, 2.95e-06, 3.11e-06, 3.38e-06, 5.07e-06]    []
# 32000     [1.94e-06, 5.83e-06, 5.20e-07, 6.59e-07, 1.57e-06, 1.31e-06, 5.25e-07, 8.98e-07]    [1.54e-06, 4.10e-06, 5.20e-07, 6.59e-07, 1.57e-06, 1.31e-06, 5.25e-07, 8.98e-07]    []
# 33000     [1.79e-06, 5.12e-06, 5.48e-07, 7.10e-07, 1.52e-06, 1.32e-06, 4.86e-07, 8.25e-07]    [1.40e-06, 3.60e-06, 5.48e-07, 7.10e-07, 1.52e-06, 1.32e-06, 4.86e-07, 8.25e-07]    []
# 34000     [1.66e-06, 4.51e-06, 8.52e-07, 1.29e-06, 1.92e-06, 2.33e-06, 1.06e-06, 1.76e-06]    [1.29e-06, 3.12e-06, 8.52e-07, 1.29e-06, 1.92e-06, 2.33e-06, 1.06e-06, 1.76e-06]    []
# 35000     [1.54e-06, 3.93e-06, 2.49e-06, 2.83e-06, 2.06e-06, 1.44e-06, 1.23e-06, 1.01e-06]    [1.18e-06, 2.92e-06, 2.49e-06, 2.83e-06, 2.06e-06, 1.44e-06, 1.23e-06, 1.01e-06]    []
# 36000     [1.46e-06, 3.62e-06, 3.16e-06, 5.11e-06, 1.59e-06, 1.52e-06, 1.21e-06, 1.40e-06]    [1.12e-06, 2.67e-06, 3.16e-06, 5.11e-06, 1.59e-06, 1.52e-06, 1.21e-06, 1.40e-06]    []
# 37000     [1.39e-06, 3.22e-06, 1.16e-06, 8.00e-07, 1.94e-06, 1.47e-06, 1.17e-06, 8.57e-07]    [1.04e-06, 2.20e-06, 1.16e-06, 8.00e-07, 1.94e-06, 1.47e-06, 1.17e-06, 8.57e-07]    []
# 38000     [1.32e-06, 2.90e-06, 6.49e-07, 3.71e-06, 1.56e-06, 4.31e-06, 7.33e-07, 3.84e-06]    [9.77e-07, 1.90e-06, 6.49e-07, 3.71e-06, 1.56e-06, 4.31e-06, 7.33e-07, 3.84e-06]    []
# 39000     [1.27e-06, 2.63e-06, 4.89e-07, 8.20e-07, 1.05e-06, 1.15e-06, 2.71e-07, 6.18e-07]    [9.42e-07, 1.81e-06, 4.89e-07, 8.20e-07, 1.05e-06, 1.15e-06, 2.71e-07, 6.18e-07]    []
# 40000     [1.20e-06, 2.41e-06, 4.11e-07, 4.57e-07, 1.01e-06, 9.74e-07, 2.49e-07, 4.33e-07]    [8.83e-07, 1.61e-06, 4.11e-07, 4.57e-07, 1.01e-06, 9.74e-07, 2.49e-07, 4.33e-07]    []
# 41000     [1.18e-06, 2.19e-06, 7.91e-07, 8.84e-07, 1.11e-06, 1.19e-06, 4.88e-07, 7.23e-07]    [8.71e-07, 1.44e-06, 7.91e-07, 8.84e-07, 1.11e-06, 1.19e-06, 4.88e-07, 7.23e-07]    []
# 42000     [1.11e-06, 2.08e-06, 1.46e-06, 8.85e-06, 2.81e-06, 6.88e-06, 2.12e-06, 6.92e-06]    [7.87e-07, 1.29e-06, 1.46e-06, 8.85e-06, 2.81e-06, 6.88e-06, 2.12e-06, 6.92e-06]    []
# 43000     [1.12e-06, 2.11e-06, 1.82e-05, 1.54e-05, 7.39e-06, 1.36e-06, 1.11e-05, 2.38e-06]    [8.25e-07, 1.62e-06, 1.82e-05, 1.54e-05, 7.39e-06, 1.36e-06, 1.11e-05, 2.38e-06]    []
# 44000     [1.03e-06, 1.78e-06, 7.39e-07, 8.78e-07, 9.27e-07, 8.91e-07, 3.33e-07, 4.72e-07]    [7.32e-07, 1.15e-06, 7.39e-07, 8.78e-07, 9.27e-07, 8.91e-07, 3.33e-07, 4.72e-07]    []
# 45000     [9.97e-07, 1.65e-06, 3.59e-07, 3.80e-07, 8.48e-07, 8.24e-07, 1.97e-07, 3.31e-07]    [7.16e-07, 1.10e-06, 3.59e-07, 3.80e-07, 8.48e-07, 8.24e-07, 1.97e-07, 3.31e-07]    []
# 46000     [9.58e-07, 1.56e-06, 3.32e-07, 3.16e-07, 8.22e-07, 7.90e-07, 1.83e-07, 2.95e-07]    [6.80e-07, 1.03e-06, 3.32e-07, 3.16e-07, 8.22e-07, 7.90e-07, 1.83e-07, 2.95e-07]    []
# 47000     [9.67e-07, 1.56e-06, 7.83e-06, 2.06e-05, 9.95e-07, 4.24e-06, 1.71e-06, 7.34e-06]    [6.72e-07, 9.80e-07, 7.83e-06, 2.06e-05, 9.95e-07, 4.24e-06, 1.71e-06, 7.34e-06]    []
# 48000     [9.02e-07, 1.39e-06, 3.24e-07, 3.06e-07, 7.81e-07, 7.48e-07, 1.69e-07, 2.73e-07]    [6.38e-07, 9.15e-07, 3.24e-07, 3.06e-07, 7.81e-07, 7.48e-07, 1.69e-07, 2.73e-07]    []
# 49000     [9.95e-07, 1.61e-06, 1.96e-05, 3.83e-05, 2.69e-06, 4.72e-06, 5.46e-06, 9.39e-06]    [7.41e-07, 1.22e-06, 1.96e-05, 3.83e-05, 2.69e-06, 4.72e-06, 5.46e-06, 9.39e-06]    []
# 50000     [8.58e-07, 1.26e-06, 1.13e-06, 2.02e-06, 8.35e-07, 1.09e-06, 3.94e-07, 8.82e-07]    [6.23e-07, 8.79e-07, 1.13e-06, 2.02e-06, 8.35e-07, 1.09e-06, 3.94e-07, 8.82e-07]    []
# 51000     [8.20e-07, 1.19e-06, 2.93e-07, 2.68e-07, 7.33e-07, 6.88e-07, 1.50e-07, 2.33e-07]    [5.78e-07, 7.91e-07, 2.93e-07, 2.68e-07, 7.33e-07, 6.88e-07, 1.50e-07, 2.33e-07]    []
# 52000     [8.07e-07, 1.13e-06, 2.95e-07, 2.76e-07, 7.19e-07, 6.71e-07, 1.51e-07, 2.28e-07]    [5.76e-07, 7.61e-07, 2.95e-07, 2.76e-07, 7.19e-07, 6.71e-07, 1.51e-07, 2.28e-07]    []
# 53000     [7.75e-07, 1.09e-06, 2.86e-07, 2.53e-07, 7.02e-07, 6.52e-07, 1.38e-07, 2.15e-07]    [5.49e-07, 7.24e-07, 2.86e-07, 2.53e-07, 7.02e-07, 6.52e-07, 1.38e-07, 2.15e-07]    []
# 54000     [7.55e-07, 1.04e-06, 2.79e-07, 2.44e-07, 6.88e-07, 6.33e-07, 1.34e-07, 2.08e-07]    [5.37e-07, 6.95e-07, 2.79e-07, 2.44e-07, 6.88e-07, 6.33e-07, 1.34e-07, 2.08e-07]    []
# 55000     [7.36e-07, 9.96e-07, 4.81e-07, 3.41e-07, 7.68e-07, 6.84e-07, 2.51e-07, 2.86e-07]    [5.21e-07, 6.61e-07, 4.81e-07, 3.41e-07, 7.68e-07, 6.84e-07, 2.51e-07, 2.86e-07]    []
# 56000     [7.14e-07, 9.58e-07, 1.34e-06, 9.03e-07, 2.02e-06, 1.72e-06, 1.72e-06, 1.10e-06]    [5.12e-07, 6.41e-07, 1.34e-06, 9.03e-07, 2.02e-06, 1.72e-06, 1.72e-06, 1.10e-06]    []
# 57000     [7.15e-07, 9.55e-07, 1.73e-06, 6.38e-06, 6.89e-07, 2.52e-06, 3.81e-07, 2.88e-06]    [4.96e-07, 6.00e-07, 1.73e-06, 6.38e-06, 6.89e-07, 2.52e-06, 3.81e-07, 2.88e-06]    []
# 58000     [6.79e-07, 8.82e-07, 2.97e-07, 2.19e-07, 6.64e-07, 5.79e-07, 1.42e-07, 1.88e-07]    [4.88e-07, 5.91e-07, 2.97e-07, 2.19e-07, 6.64e-07, 5.79e-07, 1.42e-07, 1.88e-07]    []
# 59000     [6.59e-07, 8.63e-07, 4.82e-06, 9.10e-06, 8.43e-06, 9.84e-06, 8.54e-06, 9.27e-06]    [4.70e-07, 5.57e-07, 4.82e-06, 9.10e-06, 8.43e-06, 9.84e-06, 8.54e-06, 9.27e-06]    []
# 60000     [6.60e-07, 8.27e-07, 1.42e-06, 2.40e-06, 7.67e-07, 9.04e-07, 4.94e-07, 8.47e-07]    [4.71e-07, 5.36e-07, 1.42e-06, 2.40e-06, 7.67e-07, 9.04e-07, 4.94e-07, 8.47e-07]    []
# 61000     [6.33e-07, 7.89e-07, 2.57e-07, 2.20e-07, 6.17e-07, 5.50e-07, 1.24e-07, 1.86e-07]    [4.64e-07, 5.33e-07, 2.57e-07, 2.20e-07, 6.17e-07, 5.50e-07, 1.24e-07, 1.86e-07]    []
# 62000     [6.16e-07, 7.62e-07, 2.39e-07, 1.97e-07, 5.95e-07, 5.20e-07, 1.04e-07, 1.46e-07]    [4.52e-07, 5.11e-07, 2.39e-07, 1.97e-07, 5.95e-07, 5.20e-07, 1.04e-07, 1.46e-07]    []
# 63000     [6.13e-07, 7.32e-07, 4.36e-07, 5.85e-07, 6.06e-07, 5.87e-07, 1.92e-07, 3.20e-07]    [4.55e-07, 4.92e-07, 4.36e-07, 5.85e-07, 6.06e-07, 5.87e-07, 1.92e-07, 3.20e-07]    []
# 64000     [6.14e-07, 7.16e-07, 8.60e-07, 2.03e-06, 5.91e-07, 5.46e-07, 2.98e-07, 5.65e-07]    [4.50e-07, 4.76e-07, 8.60e-07, 2.03e-06, 5.91e-07, 5.46e-07, 2.98e-07, 5.65e-07]    []
# 65000     [6.11e-07, 7.56e-07, 4.57e-06, 8.94e-06, 1.30e-06, 2.75e-06, 1.48e-06, 3.48e-06]    [4.73e-07, 5.40e-07, 4.57e-06, 8.94e-06, 1.30e-06, 2.75e-06, 1.48e-06, 3.48e-06]    []
# 66000     [5.71e-07, 6.68e-07, 3.82e-07, 4.90e-07, 6.22e-07, 1.05e-06, 1.91e-07, 5.91e-07]    [4.24e-07, 4.44e-07, 3.82e-07, 4.90e-07, 6.22e-07, 1.05e-06, 1.91e-07, 5.91e-07]    []
# 67000     [5.62e-07, 6.52e-07, 2.48e-07, 2.38e-07, 5.50e-07, 4.73e-07, 1.04e-07, 1.37e-07]    [4.23e-07, 4.38e-07, 2.48e-07, 2.38e-07, 5.50e-07, 4.73e-07, 1.04e-07, 1.37e-07]    []
# 68000     [9.68e-07, 1.50e-06, 4.25e-05, 8.60e-05, 6.77e-06, 1.50e-05, 1.50e-05, 2.90e-05]    [6.64e-07, 9.57e-07, 4.25e-05, 8.60e-05, 6.77e-06, 1.50e-05, 1.50e-05, 2.90e-05]    []
# 69000     [5.43e-07, 6.10e-07, 2.72e-07, 2.10e-07, 5.94e-07, 5.05e-07, 1.62e-07, 1.80e-07]    [4.09e-07, 4.06e-07, 2.72e-07, 2.10e-07, 5.94e-07, 5.05e-07, 1.62e-07, 1.80e-07]    []
# 70000     [5.33e-07, 5.99e-07, 1.18e-05, 7.16e-06, 1.55e-05, 9.71e-06, 1.71e-05, 9.03e-06]    [4.06e-07, 3.89e-07, 1.18e-05, 7.16e-06, 1.55e-05, 9.71e-06, 1.71e-05, 9.03e-06]    []
# 71000     [5.26e-07, 5.78e-07, 2.19e-07, 1.69e-07, 5.24e-07, 4.37e-07, 1.02e-07, 1.12e-07]    [4.00e-07, 3.81e-07, 2.19e-07, 1.69e-07, 5.24e-07, 4.37e-07, 1.02e-07, 1.12e-07]    []
# 72000     [5.25e-07, 5.69e-07, 2.78e-07, 3.25e-07, 5.15e-07, 4.67e-07, 1.20e-07, 1.75e-07]    [3.99e-07, 3.71e-07, 2.78e-07, 3.25e-07, 5.15e-07, 4.67e-07, 1.20e-07, 1.75e-07]    []
# 73000     [5.13e-07, 5.53e-07, 2.78e-07, 3.11e-07, 5.14e-07, 4.78e-07, 1.20e-07, 1.86e-07]    [3.95e-07, 3.65e-07, 2.78e-07, 3.11e-07, 5.14e-07, 4.78e-07, 1.20e-07, 1.86e-07]    []
# 74000     [5.08e-07, 5.40e-07, 2.52e-07, 2.53e-07, 4.99e-07, 4.21e-07, 1.09e-07, 1.25e-07]    [3.89e-07, 3.50e-07, 2.52e-07, 2.53e-07, 4.99e-07, 4.21e-07, 1.09e-07, 1.25e-07]    []
# 75000     [5.01e-07, 5.31e-07, 1.49e-06, 3.78e-06, 2.75e-06, 3.10e-06, 2.45e-06, 3.15e-06]    [3.90e-07, 3.55e-07, 1.49e-06, 3.78e-06, 2.75e-06, 3.10e-06, 2.45e-06, 3.15e-06]    []
# 76000     [4.91e-07, 5.07e-07, 2.08e-07, 1.57e-07, 4.94e-07, 4.03e-07, 1.03e-07, 9.56e-08]    [3.78e-07, 3.29e-07, 2.08e-07, 1.57e-07, 4.94e-07, 4.03e-07, 1.03e-07, 9.56e-08]    []
# 77000     [4.89e-07, 5.00e-07, 2.67e-07, 3.64e-07, 4.79e-07, 4.15e-07, 1.06e-07, 1.26e-07]    [3.79e-07, 3.26e-07, 2.67e-07, 3.64e-07, 4.79e-07, 4.15e-07, 1.06e-07, 1.26e-07]    []
# 78000     [4.78e-07, 4.89e-07, 1.94e-07, 1.61e-07, 4.64e-07, 3.85e-07, 8.86e-08, 8.66e-08]    [3.72e-07, 3.13e-07, 1.94e-07, 1.61e-07, 4.64e-07, 3.85e-07, 8.86e-08, 8.66e-08]    []
# 79000     [4.72e-07, 4.76e-07, 3.63e-07, 3.73e-07, 5.09e-07, 5.48e-07, 1.68e-07, 2.03e-07]    [3.69e-07, 3.06e-07, 3.63e-07, 3.73e-07, 5.09e-07, 5.48e-07, 1.68e-07, 2.03e-07]    []
# 80000     [4.66e-07, 4.66e-07, 2.62e-07, 3.59e-07, 4.60e-07, 4.07e-07, 1.01e-07, 1.37e-07]    [3.64e-07, 2.99e-07, 2.62e-07, 3.59e-07, 4.60e-07, 4.07e-07, 1.01e-07, 1.37e-07]    []
#
# Best model at step 78000:
#   train loss: 2.34e-06
#   test loss: 2.06e-06
#   test metric: []
#
# 'train' took 1741.803143 s
#
# Saving loss history to h:\毕业论文\demo\loss.dat ...
# Saving training data to h:\毕业论文\demo\train.dat ...
# Saving test data to h:\毕业论文\demo\test.dat ...
