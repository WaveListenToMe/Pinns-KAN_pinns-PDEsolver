# %% [markdown]
# To solve an inverse problem for diffusion-reaction systems for unknowns $D$ and $k_f$
#
# $\frac{\partial C_A}{\partial t}=D\frac{\partial^2C_A}{\partial x^2}-k_fC_AC_B^2,\\\frac{\partial C_B}{\partial t}=D\frac{\partial^2C_B}{\partial x^2}-2k_fC_AC_B^2$
#
# for $x \in [0,1]$ and $t \in [0,10]$ initial conditions
#
# $C_A(x,0)=C_B(x,0)=e^{-20x}$
#
# and boundary conditions
#
# $\begin{gathered}
# C_A(0,t)=C_B(0,t)=1 \\
# C_A(1,t)=C_B(1,t)=0.
# \end{gathered}$
#
# expected values of $D$ and $k_f$ are $2\cdot10^{-3} $ and $0.1$
#
# Implementation

# %%
import deepxde as dde
import numpy as np
import torch

# %% [markdown]
# Now, we define the unknown variables $D$ and $k_f$ with initial guesses of 1 and 0.05, respectively:

# %%
D = dde.Variable(1.0)
kf = dde.Variable(0.05)

# D = 2
# kf = 0.1

# %% [markdown]
# We define the computational geometries by using the built-in <u>**Interval()</u>** and <u>**TimeDomain()**</u> combining them with <u>**GeometryXTime()**</u>

# %%
geom = dde.geometry.Interval(0, 1)  #x的边界条件
timedomain = dde.geometry.TimeDomain(0, 10)  #t的边界条件
geomtime = dde.geometry.GeometryXTime(geom, timedomain)  ##combine

# %% [markdown]
# Now, we create the reaction-inverse PDE:
#
# ues Jacobian to represent 1-order Partial derivative
#
# use Hessian to represent 2-order Partial derivative
#
# Here, the first parameter is the $t$-coordinate, and it is represented by $x$
#
# The second parameter has $C_A$ and $C_B$, which are represented by $y$.

# %%
def pde(x, y):
    ca, cb = y[:, 0:1], y[:, 1:2]  ##多维数组的切片语法
    dca_t = dde.grad.jacobian(y, x, i=0, j=1)
    dca_xx = dde.grad.hessian(y, x, component=0, i=0, j=0)##等式1 eq_a

    dcb_t = dde.grad.jacobian(y, x, i=1, j=1)
    dcb_xx = dde.grad.hessian(y, x, component=1, i=0, j=0)##等式2 eq_b

    eq_a = dca_t - 1e-3 * D * dca_xx + kf * ca * cb ** 2
    eq_b = dcb_t - 1e-3 * D * dcb_xx + 2 * kf * ca * cb ** 2 
    ##构造了偏微分方程组
    return [eq_a, eq_b]

# %% [markdown]
# Next, we consider the Dirichlet boundary conditions and initial conditions:

# %%
def fun_bc(x):  ##boundary conditions 边界条件
    return 1 - x[:, 0:1]

def fun_init(x): ##initial conditions 初始条件
    return np.exp(-20 * x[:, 0:1])

##边界条件的构造
bc_a = dde.icbc.DirichletBC(
    geomtime, fun_bc, lambda _, on_boundary: on_boundary, component=0
)

bc_b = dde.icbc.DirichletBC(
    geomtime, fun_bc, lambda _, on_boundary: on_boundary, component=1
)

##初始条件的构造
ic1 = dde.icbc.IC(geomtime, fun_init, lambda _, on_initial: on_initial, component=0)
ic2 = dde.icbc.IC(geomtime, fun_init, lambda _, on_initial: on_initial, component=1)

# %% [markdown]
# Now, we generate the training data：

# %%
def gen_traindata():
    data = np.load("reaction.npz")
    t, x, ca, cb = data["t"], data["x"], data["Ca"], data["Cb"]
    X, T = np.meshgrid(x, t)
    X = np.reshape(X, (-1, 1))  ##reshape为一个 一列的二维数组
    T = np.reshape(T, (-1, 1))
    Ca = np.reshape(ca, (-1, 1))
    Cb = np.reshape(cb, (-1, 1))
    return np.hstack((X, T)), Ca, Cb  ##堆叠数组

# %% [markdown]
# After generating the data, we organize it:

# %%
observe_x, Ca, Cb = gen_traindata()
observe_y1 = dde.icbc.PointSetBC(observe_x, Ca, component=0)
observe_y2 = dde.icbc.PointSetBC(observe_x, Cb, component=1)

# %% [markdown]
# Now, we can define the <u>**TimePDE**</u> problem as follows:

# %%
data = dde.data.TimePDE(
    geomtime,
    pde,
    [bc_a, bc_b, ic1, ic2, observe_y1, observe_y2],
    # [bc_a, bc_b, ic1, ic2],
    num_domain=2000,
    num_boundary=100,
    num_initial=100,
    anchors=observe_x,
    num_test=50000,
)
# Out:
# Warning: 50000 points required, but 50055 points sampled.

# %% [markdown]
# We have 2000 training residual points in the domain, 100 points on the boundary, 100 points for the initial conditions, and 50000 to test the PDE residual. anchors specifies the training points as well.
#
# Now, we create the network:

# %%
net = dde.nn.FNN([2] + [20] * 3 + [2], "tanh", "Glorot uniform")

# %% [markdown]
# This network has two inputs, one for the $t$-coordinate and one for the $x$-coordinate, and three hidden layers with 20 neurons each.
#
# The output layer has two outputs, one for $C_A$ and one for $C_B$.
#
# Activation: tanh; Initializer: Glorot uniform.
#
# Now, we create the <u>Model</u> and specify the optimizer, learning rate, and <u>external_trainable_variables</u>.
# Also output the values of $D$ and $k_f$ every 1000 iterations.

# %%
model = dde.Model(data, net)
model.compile("adam", lr=0.001, external_trainable_variables=[kf, D])
# model.compile("adam", lr=0.001)
variable = dde.callbacks.VariableValue([kf, D], period=1000, filename="variables.dat")
# Out:
# Compiling model...
# 'compile' took 0.000668 s

# %%
# losshistory, train_state = model.train(iterations=2000)
losshistory, train_state = model.train(iterations=40000, callbacks=[variable])
# dde.saveplot(losshistory, train_state, issave=True, isplot=True)
# Out:
# Training model...
#
# Step      Train loss                                                                          Test loss                                                                           Test metric
# 0         [1.01e-03, 6.09e-03, 4.32e-01, 2.59e-01, 1.21e-01, 4.11e-02, 8.28e-02, 1.65e-01]    [9.67e-04, 5.59e-03, 4.32e-01, 2.59e-01, 1.21e-01, 4.11e-02, 8.28e-02, 1.65e-01]    []
# 1000      [1.65e-04, 1.66e-04, 2.47e-04, 1.83e-04, 4.31e-04, 3.87e-04, 2.31e-04, 1.35e-04]    [1.32e-04, 1.27e-04, 2.47e-04, 1.83e-04, 4.31e-04, 3.87e-04, 2.31e-04, 1.35e-04]    []
# 2000      [8.02e-05, 7.77e-05, 5.46e-05, 2.90e-05, 7.70e-05, 5.13e-05, 8.77e-05, 5.74e-05]    [7.14e-05, 6.51e-05, 5.46e-05, 2.90e-05, 7.70e-05, 5.13e-05, 8.77e-05, 5.74e-05]    []
# 3000      [4.74e-05, 5.46e-05, 2.89e-05, 1.50e-05, 3.35e-05, 2.08e-05, 3.03e-05, 6.65e-05]    [4.08e-05, 4.37e-05, 2.89e-05, 1.50e-05, 3.35e-05, 2.08e-05, 3.03e-05, 6.65e-05]    []
# 4000      [3.89e-05, 4.48e-05, 1.83e-05, 1.40e-05, 2.07e-05, 1.38e-05, 2.42e-05, 5.77e-05]    [3.27e-05, 3.41e-05, 1.83e-05, 1.40e-05, 2.07e-05, 1.38e-05, 2.42e-05, 5.77e-05]    []
# 5000      [3.22e-05, 3.65e-05, 1.37e-05, 1.32e-05, 1.64e-05, 1.12e-05, 2.03e-05, 5.12e-05]    [2.71e-05, 2.72e-05, 1.37e-05, 1.32e-05, 1.64e-05, 1.12e-05, 2.03e-05, 5.12e-05]    []
# 6000      [2.91e-05, 3.12e-05, 9.92e-06, 1.06e-05, 1.45e-05, 9.80e-06, 1.78e-05, 4.70e-05]    [2.48e-05, 2.36e-05, 9.92e-06, 1.06e-05, 1.45e-05, 9.80e-06, 1.78e-05, 4.70e-05]    []
# 7000      [2.66e-05, 2.80e-05, 7.68e-06, 9.30e-06, 1.26e-05, 8.55e-06, 1.53e-05, 4.36e-05]    [2.29e-05, 2.17e-05, 7.68e-06, 9.30e-06, 1.26e-05, 8.55e-06, 1.53e-05, 4.36e-05]    []
# 8000      [2.38e-05, 2.54e-05, 6.02e-06, 8.04e-06, 1.07e-05, 7.44e-06, 1.27e-05, 4.07e-05]    [2.05e-05, 2.03e-05, 6.02e-06, 8.04e-06, 1.07e-05, 7.44e-06, 1.27e-05, 4.07e-05]    []
# 9000      [2.04e-05, 2.32e-05, 5.08e-06, 7.08e-06, 8.70e-06, 6.31e-06, 1.02e-05, 3.74e-05]    [1.75e-05, 1.91e-05, 5.08e-06, 7.08e-06, 8.70e-06, 6.31e-06, 1.02e-05, 3.74e-05]    []
# 10000     [1.74e-05, 2.18e-05, 3.87e-06, 5.50e-06, 6.99e-06, 5.19e-06, 7.96e-06, 3.33e-05]    [1.49e-05, 1.81e-05, 3.87e-06, 5.50e-06, 6.99e-06, 5.19e-06, 7.96e-06, 3.33e-05]    []
# 11000     [1.46e-05, 2.12e-05, 3.39e-06, 4.45e-06, 5.68e-06, 4.12e-06, 6.15e-06, 2.75e-05]    [1.23e-05, 1.74e-05, 3.39e-06, 4.45e-06, 5.68e-06, 4.12e-06, 6.15e-06, 2.75e-05]    []
# 12000     [1.19e-05, 2.08e-05, 3.12e-06, 3.43e-06, 4.94e-06, 3.28e-06, 4.95e-06, 2.13e-05]    [9.90e-06, 1.65e-05, 3.12e-06, 3.43e-06, 4.94e-06, 3.28e-06, 4.95e-06, 2.13e-05]    []
# 13000     [9.42e-06, 1.97e-05, 2.83e-06, 2.42e-06, 4.54e-06, 2.65e-06, 4.32e-06, 1.58e-05]    [7.61e-06, 1.51e-05, 2.83e-06, 2.42e-06, 4.54e-06, 2.65e-06, 4.32e-06, 1.58e-05]    []
# 14000     [7.63e-06, 1.81e-05, 2.48e-06, 2.02e-06, 4.09e-06, 2.17e-06, 3.77e-06, 1.07e-05]    [5.94e-06, 1.34e-05, 2.48e-06, 2.02e-06, 4.09e-06, 2.17e-06, 3.77e-06, 1.07e-05]    []
# 15000     [6.29e-06, 1.58e-05, 2.19e-06, 1.66e-06, 3.63e-06, 1.79e-06, 3.30e-06, 6.95e-06]    [4.73e-06, 1.10e-05, 2.19e-06, 1.66e-06, 3.63e-06, 1.79e-06, 3.30e-06, 6.95e-06]    []
# 16000     [5.30e-06, 1.29e-05, 2.06e-06, 1.72e-06, 3.14e-06, 1.48e-06, 2.75e-06, 4.06e-06]    [3.91e-06, 8.54e-06, 2.06e-06, 1.72e-06, 3.14e-06, 1.48e-06, 2.75e-06, 4.06e-06]    []
# 17000     [4.44e-06, 1.02e-05, 1.72e-06, 1.26e-06, 2.75e-06, 1.24e-06, 2.00e-06, 2.29e-06]    [3.26e-06, 6.23e-06, 1.72e-06, 1.26e-06, 2.75e-06, 1.24e-06, 2.00e-06, 2.29e-06]    []
# 18000     [3.58e-06, 7.42e-06, 1.54e-06, 1.14e-06, 2.42e-06, 1.04e-06, 1.45e-06, 1.20e-06]    [2.68e-06, 4.24e-06, 1.54e-06, 1.14e-06, 2.42e-06, 1.04e-06, 1.45e-06, 1.20e-06]    []
# 19000     [2.90e-06, 4.94e-06, 7.92e-06, 7.33e-06, 4.31e-06, 1.59e-06, 4.98e-06, 4.06e-06]    [2.36e-06, 2.48e-06, 7.92e-06, 7.33e-06, 4.31e-06, 1.59e-06, 4.98e-06, 4.06e-06]    []
# 20000     [2.30e-06, 3.69e-06, 5.44e-06, 4.77e-06, 3.53e-06, 1.34e-06, 3.59e-06, 2.36e-06]    [1.94e-06, 1.79e-06, 5.44e-06, 4.77e-06, 3.53e-06, 1.34e-06, 3.59e-06, 2.36e-06]    []
# 21000     [1.79e-06, 2.85e-06, 1.04e-06, 8.68e-07, 1.70e-06, 6.93e-07, 5.66e-07, 3.07e-07]    [1.46e-06, 1.52e-06, 1.04e-06, 8.68e-07, 1.70e-06, 6.93e-07, 5.66e-07, 3.07e-07]    []
# 22000     [1.50e-06, 2.22e-06, 9.47e-07, 8.02e-07, 1.49e-06, 6.35e-07, 4.59e-07, 2.58e-07]    [1.23e-06, 1.23e-06, 9.47e-07, 8.02e-07, 1.49e-06, 6.35e-07, 4.59e-07, 2.58e-07]    []
# 23000     [1.31e-06, 1.82e-06, 1.65e-06, 2.10e-06, 1.44e-06, 8.62e-07, 6.72e-07, 6.68e-07]    [1.07e-06, 1.11e-06, 1.65e-06, 2.10e-06, 1.44e-06, 8.62e-07, 6.72e-07, 6.68e-07]    []
# 24000     [1.14e-06, 1.59e-06, 7.34e-07, 6.51e-07, 1.17e-06, 5.51e-07, 3.12e-07, 2.05e-07]    [9.24e-07, 9.46e-07, 7.34e-07, 6.51e-07, 1.17e-06, 5.51e-07, 3.12e-07, 2.05e-07]    []
# 25000     [1.06e-06, 1.42e-06, 7.39e-07, 7.47e-07, 1.05e-06, 5.46e-07, 3.12e-07, 3.08e-07]    [8.57e-07, 8.69e-07, 7.39e-07, 7.47e-07, 1.05e-06, 5.46e-07, 3.12e-07, 3.08e-07]    []
# 26000     [9.75e-07, 1.33e-06, 1.46e-06, 3.78e-06, 1.01e-06, 1.53e-06, 4.58e-07, 1.99e-06]    [7.70e-07, 9.23e-07, 1.46e-06, 3.78e-06, 1.01e-06, 1.53e-06, 4.58e-07, 1.99e-06]    []
# 27000     [9.11e-07, 1.23e-06, 5.79e-07, 5.14e-07, 8.68e-07, 4.60e-07, 2.09e-07, 1.71e-07]    [7.18e-07, 7.91e-07, 5.79e-07, 5.14e-07, 8.68e-07, 4.60e-07, 2.09e-07, 1.71e-07]    []
# 28000     [8.58e-07, 1.17e-06, 5.76e-07, 4.90e-07, 8.20e-07, 4.39e-07, 1.98e-07, 1.63e-07]    [6.69e-07, 7.59e-07, 5.76e-07, 4.90e-07, 8.20e-07, 4.39e-07, 1.98e-07, 1.63e-07]    []
# 29000     [8.05e-07, 1.13e-06, 4.98e-07, 4.25e-07, 7.58e-07, 4.15e-07, 1.69e-07, 1.51e-07]    [6.20e-07, 7.22e-07, 4.98e-07, 4.25e-07, 7.58e-07, 4.15e-07, 1.69e-07, 1.51e-07]    []
# 30000     [7.76e-07, 1.07e-06, 4.73e-07, 3.95e-07, 7.16e-07, 4.03e-07, 1.51e-07, 1.44e-07]    [5.96e-07, 6.98e-07, 4.73e-07, 3.95e-07, 7.16e-07, 4.03e-07, 1.51e-07, 1.44e-07]    []
# 31000     [7.37e-07, 1.03e-06, 4.52e-07, 3.69e-07, 6.78e-07, 3.85e-07, 1.38e-07, 1.35e-07]    [5.61e-07, 6.70e-07, 4.52e-07, 3.69e-07, 6.78e-07, 3.85e-07, 1.38e-07, 1.35e-07]    []
# 32000     [7.06e-07, 9.96e-07, 4.45e-07, 3.75e-07, 6.42e-07, 3.75e-07, 1.30e-07, 1.38e-07]    [5.32e-07, 6.44e-07, 4.45e-07, 3.75e-07, 6.42e-07, 3.75e-07, 1.30e-07, 1.38e-07]    []
# 33000     [6.77e-07, 9.59e-07, 4.23e-07, 3.31e-07, 6.15e-07, 3.60e-07, 1.19e-07, 1.25e-07]    [5.08e-07, 6.20e-07, 4.23e-07, 3.31e-07, 6.15e-07, 3.60e-07, 1.19e-07, 1.25e-07]    []
# 34000     [6.54e-07, 9.26e-07, 4.29e-07, 3.42e-07, 5.90e-07, 3.52e-07, 1.19e-07, 1.30e-07]    [4.88e-07, 6.01e-07, 4.29e-07, 3.42e-07, 5.90e-07, 3.52e-07, 1.19e-07, 1.30e-07]    []
# 35000     [6.21e-07, 9.02e-07, 3.94e-07, 2.95e-07, 5.66e-07, 3.38e-07, 1.04e-07, 1.13e-07]    [4.57e-07, 5.76e-07, 3.94e-07, 2.95e-07, 5.66e-07, 3.38e-07, 1.04e-07, 1.13e-07]    []
# 36000     [6.09e-07, 8.93e-07, 6.93e-07, 1.82e-06, 7.34e-07, 9.15e-07, 2.89e-07, 1.13e-06]    [4.56e-07, 6.10e-07, 6.93e-07, 1.82e-06, 7.34e-07, 9.15e-07, 2.89e-07, 1.13e-06]    []
# 37000     [5.78e-07, 8.44e-07, 3.65e-07, 2.59e-07, 5.23e-07, 3.20e-07, 9.08e-08, 1.03e-07]    [4.21e-07, 5.37e-07, 3.65e-07, 2.59e-07, 5.23e-07, 3.20e-07, 9.08e-08, 1.03e-07]    []
# 38000     [5.68e-07, 8.17e-07, 7.38e-07, 8.12e-07, 5.69e-07, 4.12e-07, 2.29e-07, 2.65e-07]    [4.10e-07, 5.27e-07, 7.38e-07, 8.12e-07, 5.69e-07, 4.12e-07, 2.29e-07, 2.65e-07]    []
# 39000     [5.43e-07, 7.92e-07, 3.41e-07, 2.34e-07, 4.85e-07, 3.04e-07, 8.11e-08, 9.53e-08]    [3.90e-07, 5.04e-07, 3.41e-07, 2.34e-07, 4.85e-07, 3.04e-07, 8.11e-08, 9.53e-08]    []
# 40000     [6.64e-07, 1.03e-06, 2.06e-05, 1.38e-05, 8.27e-06, 1.57e-06, 1.20e-05, 2.85e-06]    [4.78e-07, 7.06e-07, 2.06e-05, 1.38e-05, 8.27e-06, 1.57e-06, 1.20e-05, 2.85e-06]    []
#
# Best model at step 39000:
#   train loss: 2.88e-06
#   test loss: 2.43e-06
#   test metric: []
#
# 'train' took 886.129167 s

# %%
from matplotlib import cm
from matplotlib.ticker import FormatStrFormatter, LinearLocator
import matplotlib.pyplot as plt
x = np.linspace(0, 1.0, 256)
t = np.linspace(0, 10, 100)
X, T = np.meshgrid(x, t)
X_star = np.hstack((X.flatten()[:, None], T.flatten()[:, None]))
prediction = model.predict(X_star, operator=None)
c_a = prediction[:,0].reshape(100,256)
c_b = prediction[:,1].reshape(100,256)

# x = np.ravel(X).reshape(-1, 1)
# t = np.ravel(T).reshape(-1, 1)

fig, ax = plt.subplots(1 ,2 ,subplot_kw={'projection': '3d'}, figsize=(10, 10))
# ax = fig.add_subplot(projection='3d')
ax[0].set_zlim([0, 1])
ax[0].plot_surface(X, T, c_a, cmap=cm.RdYlBu_r, edgecolor='blue', linewidth=0.0003, antialiased=True)
ax[0].set_xlabel('x')
ax[0].set_ylabel('t')
ax[0].set_zlabel('C_a')
ax[0].set_title('C_a.') 

ax[1].set_zlim([0, 1])
ax[1].plot_surface(X, T, c_b, cmap=cm.RdYlBu_r, edgecolor='blue', linewidth=0.0003, antialiased=True)
ax[1].set_xlabel('x')
ax[1].set_ylabel('t')
ax[1].set_zlabel('C_b')
ax[1].set_title('C_b.') 
# plt.savefig('KAN.png')
plt.show(fig)
